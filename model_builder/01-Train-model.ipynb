# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Get Data

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# # Create model with Autokeras

# %%
##!pip install autokeras==1.0.12
# Out:
# WARNING: The directory '/home/jovyan/.cache/pip' or its parent directory is not owned or is not writable by the current user. The cache has been disabled. Check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.
# Collecting autokeras==1.0.12
#   Downloading autokeras-1.0.12-py3-none-any.whl (164 kB)
#      |████████████████████████████████| 164 kB 22.2 MB/s
# Collecting keras-tuner>=1.0.2
#   Downloading keras-tuner-1.0.2.tar.gz (62 kB)
#      |████████████████████████████████| 62 kB 26.3 MB/s
# Requirement already satisfied: packaging in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from autokeras==1.0.12) (20.8)
# Requirement already satisfied: scikit-learn in /opt/venv/lib/python3.7/site-packages (from autokeras==1.0.12) (0.23.2)
# Requirement already satisfied: pandas in /opt/venv/lib/python3.7/site-packages (from autokeras==1.0.12) (1.0.5)
# Collecting tensorflow>=2.3.0
#   Downloading tensorflow-2.4.1-cp37-cp37m-manylinux2010_x86_64.whl (394.3 MB)
#      |███████████████████████▉        | 294.3 MB 81.9 MB/s eta 0:00:02IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
#      |████████████████████████████████| 394.3 MB 104.9 MB/s
# Collecting future
#   Downloading future-0.18.2.tar.gz (829 kB)
#      |████████████████████████████████| 829 kB 100.1 MB/s
# Requirement already satisfied: numpy in /opt/venv/lib/python3.7/site-packages (from keras-tuner>=1.0.2->autokeras==1.0.12) (1.19.4)
# Collecting tabulate
#   Downloading tabulate-0.8.7-py3-none-any.whl (24 kB)
# Collecting terminaltables
#   Downloading terminaltables-3.1.0.tar.gz (12 kB)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Collecting tqdm
#   Downloading tqdm-4.56.0-py2.py3-none-any.whl (72 kB)
#      |████████████████████████████████| 72 kB 44.3 MB/s
# Requirement already satisfied: requests in /opt/venv/lib/python3.7/site-packages (from keras-tuner>=1.0.2->autokeras==1.0.12) (2.25.0)
# Requirement already satisfied: scipy in /opt/venv/lib/python3.7/site-packages (from keras-tuner>=1.0.2->autokeras==1.0.12) (1.5.4)
# Requirement already satisfied: pyparsing>=2.0.2 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from packaging->autokeras==1.0.12) (2.4.7)
# Requirement already satisfied: joblib>=0.11 in /opt/venv/lib/python3.7/site-packages (from scikit-learn->autokeras==1.0.12) (0.17.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/venv/lib/python3.7/site-packages (from scikit-learn->autokeras==1.0.12) (2.1.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from pandas->autokeras==1.0.12) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /opt/venv/lib/python3.7/site-packages (from pandas->autokeras==1.0.12) (2020.4)
# Collecting grpcio~=1.32.0
#   Downloading grpcio-1.32.0-cp37-cp37m-manylinux2014_x86_64.whl (3.8 MB)
#      |████████████████████████████████| 3.8 MB 43.3 MB/s
# Collecting tensorflow-estimator<2.5.0,>=2.4.0
#   Downloading tensorflow_estimator-2.4.0-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 89.0 MB/s
# Requirement already satisfied: typing-extensions~=3.7.4 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from tensorflow>=2.3.0->autokeras==1.0.12) (3.7.4.3)
# Collecting keras-preprocessing~=1.1.2
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 38.6 MB/s
# Collecting opt-einsum~=3.3.0
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 73.1 MB/s
# Requirement already satisfied: wheel~=0.35 in /opt/venv/lib/python3.7/site-packages (from tensorflow>=2.3.0->autokeras==1.0.12) (0.35.1)
# Collecting astunparse~=1.6.3
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting wrapt~=1.12.1
#   Downloading wrapt-1.12.1.tar.gz (27 kB)
# Collecting flatbuffers~=1.12.0
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting google-pasta~=0.2
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 74.5 MB/s
# Requirement already satisfied: six~=1.15.0 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from tensorflow>=2.3.0->autokeras==1.0.12) (1.15.0)
# Collecting protobuf>=3.9.2
#   Downloading protobuf-3.14.0-cp37-cp37m-manylinux1_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 99.9 MB/s
# Collecting tensorboard~=2.4
#   Downloading tensorboard-2.4.1-py3-none-any.whl (10.6 MB)
#      |████████████████████████████████| 10.6 MB 93.0 MB/s
# Collecting absl-py~=0.10
#   Downloading absl_py-0.11.0-py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 96.6 MB/s
# Collecting termcolor~=1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Collecting gast==0.3.3
#   Downloading gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# Collecting h5py~=2.10.0
#   Downloading h5py-2.10.0-cp37-cp37m-manylinux1_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 40.1 MB/s
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/venv/lib/python3.7/site-packages (from requests->keras-tuner>=1.0.2->autokeras==1.0.12) (1.26.2)
# Requirement already satisfied: idna<3,>=2.5 in /opt/venv/lib/python3.7/site-packages (from requests->keras-tuner>=1.0.2->autokeras==1.0.12) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/venv/lib/python3.7/site-packages (from requests->keras-tuner>=1.0.2->autokeras==1.0.12) (2020.11.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/venv/lib/python3.7/site-packages (from requests->keras-tuner>=1.0.2->autokeras==1.0.12) (3.0.4)
# Collecting werkzeug>=0.11.15
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
#      |████████████████████████████████| 298 kB 105.6 MB/s
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.0-py3-none-any.whl (781 kB)
#      |████████████████████████████████| 781 kB 101.2 MB/s
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.3.3-py3-none-any.whl (96 kB)
#      |████████████████████████████████| 96 kB 85.8 MB/s
# Requirement already satisfied: setuptools>=41.0.0 in /opt/venv/lib/python3.7/site-packages (from tensorboard~=2.4->tensorflow>=2.3.0->autokeras==1.0.12) (50.3.2)
# Collecting google-auth<2,>=1.6.3
#   Downloading google_auth-1.24.0-py2.py3-none-any.whl (114 kB)
#      |████████████████████████████████| 114 kB 85.1 MB/s
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.2-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from markdown>=2.6.8->tensorboard~=2.4->tensorflow>=2.3.0->autokeras==1.0.12) (3.3.0)
# Collecting rsa<5,>=3.1.4; python_version >= "3.6"
#   Downloading rsa-4.7-py3-none-any.whl (34 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
#      |████████████████████████████████| 155 kB 87.2 MB/s
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.2.0-py3-none-any.whl (12 kB)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: zipp>=0.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard~=2.4->tensorflow>=2.3.0->autokeras==1.0.12) (3.4.0)
# Collecting pyasn1>=0.1.3
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 73.8 MB/s
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
#      |████████████████████████████████| 147 kB 105.7 MB/s
# Building wheels for collected packages: keras-tuner, future, terminaltables, wrapt, termcolor
#   Building wheel for keras-tuner (setup.py) ... done
#   Created wheel for keras-tuner: filename=keras_tuner-1.0.2-py3-none-any.whl size=78936 sha256=79ca4ff6b151a23c3c2f6defd27a985d7f4835926e76ad5274bdaec3d3c1f36e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-i6r14i3_/wheels/78/e2/80/7fe373cad54ad22b06d0d6204cbc29cead9e69bb2680327775
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491059 sha256=2a38dcb27ced9f1456625476ba66141deebff3f2ff83e0bf818eceecef9158d3
#   Stored in directory: /tmp/pip-ephem-wheel-cache-i6r14i3_/wheels/56/b0/fe/4410d17b32f1f0c3cf54cdfb2bc04d7b4b8f4ae377e2229ba0
#   Building wheel for terminaltables (setup.py) ... done
#   Created wheel for terminaltables: filename=terminaltables-3.1.0-py3-none-any.whl size=15354 sha256=23f5e45152abd7f893c47f7c6054df7a3131e176d2f0bea867263319c1d829c5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-i6r14i3_/wheels/ba/ad/c8/2d98360791161cd3db6daf6b5e730f34021fc9367d5879f497
#   Building wheel for wrapt (setup.py) ... done
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp37-cp37m-linux_x86_64.whl size=33281 sha256=3864de395710187367d3929b0a6d6376cdbbd7e67a4f8ecd24a4ee7085d7b9ff
#   Stored in directory: /tmp/pip-ephem-wheel-cache-i6r14i3_/wheels/62/76/4c/aa25851149f3f6d9785f6c869387ad82b3fd37582fa8147ac6
#   Building wheel for termcolor (setup.py) ... done
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4830 sha256=d438302c5cd1368ce7d9e101e77d8e7d7d2339823fd6c27758c7018af4800e6c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-i6r14i3_/wheels/3f/e3/ec/8a8336ff196023622fbcb36de0c5a5c218cbb24111d1d4c7f2
# Successfully built keras-tuner future terminaltables wrapt termcolor
# Installing collected packages: future, tabulate, terminaltables, colorama, tqdm, keras-tuner, grpcio, tensorflow-estimator, keras-preprocessing, opt-einsum, astunparse, wrapt, flatbuffers, google-pasta, protobuf, werkzeug, tensorboard-plugin-wit, markdown, pyasn1, rsa, pyasn1-modules, cachetools, google-auth, absl-py, oauthlib, requests-oauthlib, google-auth-oauthlib, tensorboard, termcolor, gast, h5py, tensorflow, autokeras
# Successfully installed absl-py-0.11.0 astunparse-1.6.3 autokeras-1.0.12 cachetools-4.2.0 colorama-0.4.4 flatbuffers-1.12 future-0.18.2 gast-0.3.3 google-auth-1.24.0 google-auth-oauthlib-0.4.2 google-pasta-0.2.0 grpcio-1.32.0 h5py-2.10.0 keras-preprocessing-1.1.2 keras-tuner-1.0.2 markdown-3.3.3 oauthlib-3.1.0 opt-einsum-3.3.0 protobuf-3.14.0 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-oauthlib-1.3.0 rsa-4.7 tabulate-0.8.7 tensorboard-2.4.1 tensorboard-plugin-wit-1.8.0 tensorflow-2.4.1 tensorflow-estimator-2.4.0 termcolor-1.1.0 terminaltables-3.1.0 tqdm-4.56.0 werkzeug-1.0.1 wrapt-1.12.1
# WARNING: You are using pip version 20.2.4; however, version 20.3.3 is available.
# You should consider upgrading via the '/opt/venv/bin/python -m pip install --upgrade pip' command.

# %%
import autokeras as ak

# %%
clf = ak.ImageClassifier(max_trials=1)

# %%
clf.fit(np.array(x_train), np.array(y_train), epochs=1)
# Out:
# Trial 1 Complete [00h 02m 03s]
# val_loss: 0.0695454478263855
#
# Best val_loss So Far: 0.0695454478263855
# Total elapsed time: 00h 02m 03s
# INFO:tensorflow:Oracle triggered exit
# 1875/1875 [==============================] - 145s 77ms/step - loss: 0.2987 - accuracy: 0.9076
# INFO:tensorflow:Assets written to: ./image_classifier/best_model/assets

# %%
model = clf.export_model()

# %%
#from tensorflow.keras.models import load_model
#import autokeras as ak
#model = load_model("../model_builder/model_autokeras", custom_objects=ak.CUSTOM_OBJECTS)
#model.save('my_model.h5')
# Out:
# INFO:tensorflow:Assets written to: model.tf/assets

# %%
try:
    model.save("model_autokeras", save_format="tf")
except:
    model.save("model_autokeras.h5")
# Out:
# INFO:tensorflow:Assets written to: model_autokeras/assets

# %%
x_train.shape
# Out:
# (60000, 28, 28)
